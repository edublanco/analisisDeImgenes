# %% [markdown]
# # Extraccion de datos (valores de pixel) de una imagen con Python

# %%
from PIL import Image
import numpy as np
from matplotlib import pyplot as plt
foto = Image.open('img/1.jpg')
 
plt.imshow(foto)
plt.title('orig picture')
plt.show()

# %%
datos=foto.getdata()

# %% [markdown]
# es forzoso introducir el par numerico dentro de otro parentesis ya que solo acepta las coordenadas en forma de tupla
# #### dato_pixel = foto.getpixel((coordenada_x, coordenada_y))

# %%
dato_pixel = foto.getpixel((100,200,))
dato_pixel
# Out:
# (111, 111, 111)
